# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("onlinefoods.csv")
df
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
df.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
df.tail()
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 383              Post Graduate            2   12.9766    77.5993    560001
# 384              Post Graduate            4   12.9854    77.7081    560048
# 385              Post Graduate            5   12.9850    77.5533    560010
# 386              Post Graduate            2   12.9770    77.5773    560009
# 387              Post Graduate            5   12.8988    77.5764    560078
#
#     Output  Feedback Unnamed: 12
# 383    Yes  Positive         Yes
# 384    Yes  Positive         Yes
# 385    Yes  Positive         Yes
# ...

# %%
df.shape
# Out:
# (388, 13)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'latitude', 'longitude',
#        'Pin code', 'Output', 'Feedback', 'Unnamed: 12'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                             int64
# Gender                         object
# Marital Status                 object
# Occupation                     object
# Monthly Income                 object
# Educational Qualifications     object
# Family size                     int64
# latitude                      float64
# longitude                     float64
# Pin code                        int64
# Output                         object
# Feedback                       object
# Unnamed: 12                    object
# dtype: object

# %%
df["Monthly Income"].unique()
# Out:
# array(['No Income', 'Below Rs.10000', 'More than 50000', '10001 to 25000',
#        '25001 to 50000'], dtype=object)

# %%
df.nunique()
# Out:
# Age                           16
# Gender                         2
# Marital Status                 3
# Occupation                     4
# Monthly Income                 5
# Educational Qualifications     5
# Family size                    6
# latitude                      77
# longitude                     76
# Pin code                      77
# Output                         2
# Feedback                       2
# Unnamed: 12                    2
# dtype: int64

# %%
df["Marital Status"].unique()
# Out:
# array(['Single', 'Married', 'Prefer not to say'], dtype=object)

# %%
df["Occupation"].unique()
# Out:
# array(['Student', 'Employee', 'Self Employeed', 'House wife'],
#       dtype=object)

# %%
df["Educational Qualifications"].unique()
# Out:
# array(['Post Graduate', 'Graduate', 'Ph.D', 'Uneducated', 'School'],
#       dtype=object)

# %%
df["Age"].unique()
# Out:
# array([20, 24, 22, 27, 23, 21, 28, 25, 32, 30, 31, 26, 18, 19, 33, 29],
#       dtype=int64)

# %%
df.describe()
# Out:
#               Age  Family size    latitude   longitude       Pin code
# count  388.000000   388.000000  388.000000  388.000000     388.000000
# mean    24.628866     3.280928   12.972058   77.600160  560040.113402
# std      2.975593     1.351025    0.044489    0.051354      31.399609
# min     18.000000     1.000000   12.865200   77.484200  560001.000000
# 25%     23.000000     2.000000   12.936900   77.565275  560010.750000
# 50%     24.000000     3.000000   12.977000   77.592100  560033.500000
# 75%     26.000000     4.000000   12.997025   77.630900  560068.000000
# max     33.000000     6.000000   13.102000   77.758200  560109.000000

# %%
df["Monthly Income"].value_counts()
# Out:
# Monthly Income
# No Income          187
# 25001 to 50000      69
# More than 50000     62
# 10001 to 25000      45
# Below Rs.10000      25
# Name: count, dtype: int64

# %% [markdown]
# ## No Income Source -> KEY

# %%
df["Marital Status"].value_counts()
# Out:
# Marital Status
# Single               268
# Married              108
# Prefer not to say     12
# Name: count, dtype: int64

# %%
df["Occupation"].value_counts()
# Out:
# Occupation
# Student           207
# Employee          118
# Self Employeed     54
# House wife          9
# Name: count, dtype: int64

# %%
df["Age"].value_counts()
# Out:
# Age
# 23    73
# 22    57
# 25    52
# 24    50
# 26    35
# 21    23
# 27    21
# 32    16
# 28    15
# 29    14
# 20     9
# 30     9
# 31     8
# 19     4
# 18     1
# 33     1
# Name: count, dtype: int64

# %% [markdown]
# ## Young Gneration is at Peak Ordering.

# %%
df.isnull()
# Out:
#        Age  Gender  Marital Status  Occupation  Monthly Income  \
# 0    False   False           False       False           False
# 1    False   False           False       False           False
# 2    False   False           False       False           False
# 3    False   False           False       False           False
# 4    False   False           False       False           False
# ..     ...     ...             ...         ...             ...
# 383  False   False           False       False           False
# 384  False   False           False       False           False
# 385  False   False           False       False           False
# 386  False   False           False       False           False
# 387  False   False           False       False           False
#
#      Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                         False        False     False      False     False
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df["Occupation"].value_counts().plot(kind="pie",color="magenta",autopct="%.0f%%")
# df["Occupation"].value_counts().plot(kind="bar",color="green")
plt.title("Occupation Bar")
# plt.grid(True)
# plt.xlabel("X-Axis")
# plt.ylabel("Y-Axis")
# Out:
# Text(0.5, 1.0, 'Occupation Bar')

# %% [markdown]
# ### Student Key

# %%
plt.figure(figsize=(8, 6))
df["Gender"].value_counts().plot(kind="bar",color="pink")
plt.grid(True)
plt.xlabel("X-Axis(Gender)")
plt.ylabel("Y-Axis(Strength)")
# sns.countplot(data=df, x='Gender')
# sns.countplot(data=df,color="red",x="Gender")
# Out:
# Text(0, 0.5, 'Y-Axis(Strength)')

# %% [markdown]
# ### Male Index is High

# %%
# df["Monthly Income"].value_counts().plot(kind="pie")
plt.figure(figsize=(10,5))
df["Monthly Income"].value_counts().plot(kind="bar",color="red",label="Income Votality")
plt.xlabel("X-Axis(INR)")
plt.ylabel("Y-Axis(Count)")
plt.grid(True)
plt.legend()
plt.title("Income Bio")
# Out:
# Text(0.5, 1.0, 'Income Bio')

# %% [markdown]
# ## No Income Key

# %%
df["Marital Status"].value_counts().plot(kind="pie",autopct="%.0f%%")
plt.title("Married Status")
# Out:
# Text(0.5, 1.0, 'Married Status')

# %% [markdown]
# ### Marketing Key Single's

# %%
plt.figure(figsize=(9,6))
sns.countplot(data=df,x="Gender",hue="Occupation")
plt.grid(True)

# %% [markdown]
# ### Female Employed < Male Employed & Student Male > Student Female

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, x="Gender",hue="Marital Status")
plt.grid(True)

# %% [markdown]
# ### Male Married > Prefer More For The Products Launch

# %%
plt.figure(figsize=(7,5))
feedback_group_by=df.groupby("Feedback").size()
plt.pie(feedback_group_by,labels=feedback_group_by.index,autopct='%.0f%%')
plt.title("Distribution of Feedback")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df,x="Occupation",hue="Feedback")
plt.xlabel("Occupation",fontweight="bold")
plt.ylabel("Count",fontweight="bold")
plt.grid(True)

# %%
plt.figure(figsize=(8,6))
# sns.countplot(data=df,x="Monthly Income" , hue="Feedback")
sns.histplot(df["Monthly Income"],kde=True,color="b")
plt.grid(True)
plt.title("Income vs Opinions Count",fontweight="bold")
plt.xlabel("Range of Income",fontweight="bold")
plt.ylabel("Aggressive Opinions Count",fontweight="bold")
# Out:
# Text(0, 0.5, 'Aggressive Opinions Count')

# %%
plt.figure(figsize=(10,8))
sns.countplot(data=df,x="Monthly Income",hue="Family size")
plt.title("Comparison of Family Size vs Income",fontweight="bold")
plt.xlabel("Income",fontweight="bold")
plt.ylabel("Family Size",fontweight="bold")
# Out:
# Text(0, 0.5, 'Family Size')

# %% [markdown]
# ### Successfully Accomplished the target customers.

# %% [markdown]
# ### © Made with ♥ by Ayush Siloiya
